# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("C:\\Users\\Blaine\\Documents\\College\\Bootcamp\\World_Weather_Analysis\\Weather_Database\\WeatherPy_Database.csv")
city_data_df.head()
# Out:
#    City_ID         City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0      Ushuaia      AR -54.8000  -68.3000    40.658        93
# 1        1       Atuona      PF  -9.8000 -139.0333    78.854        78
# 2        2  Ferme-Neuve      CA  46.7001  -75.4493    41.288        59
# 3        3   Butaritari      KI   3.0707  172.7902    79.628        80
# 4        4    Jamestown      US  42.0970  -79.2353    47.948        41
#
#    Cloudiness  Wind Speed      Current Description
# 0         100        6.17  light intensity drizzle
# 1          26        7.61         scattered clouds
# 2          49        1.97         scattered clouds
# 3          76        2.59               light rain
# 4         100        1.34          overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 1         1        Atuona      PF  -9.8000 -139.0333    78.854        78
# 3         3    Butaritari      KI   3.0707  172.7902    79.628        80
# 6         6  Puerto Ayora      EC  -0.7393  -90.3518    80.564        91
# 11       11        Lakota      CI   5.8528   -5.6883    87.944        57
# 13       13     Mount Isa      AU -20.7333  139.5000    83.966        26
# 16       16       Rikitea      PF -23.1203 -134.9692    78.908        73
# 24       24      Saldanha      ZA -33.0117   17.9442    84.254        53
# 26       26        Olinda      BR  -8.0089  -34.8553    85.730        62
# 32       32        Castro      BR -24.7911  -50.0119    77.054        56
# 35       35  Komsomolskiy      UZ  40.4272   71.7189    77.720        33
#
#     Cloudiness  Wind Speed Current Description
# 1           26        7.61    scattered clouds
# 3           76        2.59          light rain
# 6          100        1.34     overcast clouds
# 11          87        1.95     overcast clouds
# 13          12        2.57          light rain
# 16           2        8.90           clear sky
# 24           0        4.74           clear sky
# 26          40        3.09    scattered clouds
# 32          59        3.00       moderate rain
# 35          88        1.03     overcast clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                3
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()

# %%
clean_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
clean_df
# Out:
#      City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 1          1          Atuona      PF  -9.8000 -139.0333    78.854        78
# 3          3      Butaritari      KI   3.0707  172.7902    79.628        80
# 6          6    Puerto Ayora      EC  -0.7393  -90.3518    80.564        91
# 11        11          Lakota      CI   5.8528   -5.6883    87.944        57
# 13        13       Mount Isa      AU -20.7333  139.5000    83.966        26
# ..       ...             ...     ...      ...       ...       ...       ...
# 660      660    Mount Darwin      ZW -16.7725   31.5838    77.090        56
# 662      662       Alyangula      AU -13.8483  136.4192    78.674        94
# 666      666  Nisia Floresta      BR  -6.0911  -35.2086    88.178        52
# 667      667          Muncar      ID  -8.4333  114.3333    75.866        83
# 672      672       Kaohsiung      TW  22.6163  120.3133    79.034        70
#
#      Cloudiness  Wind Speed Current Description
# 1            26        7.61    scattered clouds
# 3            76        2.59          light rain
# 6           100        1.34     overcast clouds
# 11           87        1.95     overcast clouds
# 13           12        2.57          light rain
# ..          ...         ...                 ...
# 660          64        1.35       broken clouds
# 662          40        0.00    scattered clouds
# 666          89        4.30          light rain
# 667          79        0.36       broken clouds
# 672          20        2.06          few clouds
#
# [208 rows x 10 columns]

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#             City Country  Max Temp      Lat       Lng Hotel Name
# 1         Atuona      PF    78.854  -9.8000 -139.0333
# 3     Butaritari      KI    79.628   3.0707  172.7902
# 6   Puerto Ayora      EC    80.564  -0.7393  -90.3518
# 11        Lakota      CI    87.944   5.8528   -5.6883
# 13     Mount Isa      AU    83.966 -20.7333  139.5000
# 16       Rikitea      PF    78.908 -23.1203 -134.9692
# 24      Saldanha      ZA    84.254 -33.0117   17.9442
# 26        Olinda      BR    85.730  -8.0089  -34.8553
# 32        Castro      BR    77.054 -24.7911  -50.0119
# 35  Komsomolskiy      UZ    77.720  40.4272   71.7189

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 24141,
    "type": "lodging",
    "key": g_key,
    "location": "42.65, -73.75"}

# Use base URL to search for hotels.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEAxZBx7hqZ0zMO-GxnQTv0zFP_MfF5p5z55TjIW9Ex1X58h0eniuFDXA9z0mlQmgErtk8NHu_w5sxltT8Nuc1sM5i3LnQf_PjC3VhrJ0HDujhrENZhpYqj5YYVmRIMDJg8J_J-fFBtoHgLb4qXEmQl371zkHf-KQOHtwEeHv_vrXyZreXFDbAkp25G1psQeOJHqNsM1vExLKlUZHNIWbVqWC1GFFPzDBoq6jJAJiRKRx5jLwn_XUhImWDIvRJOJO2zubYkQeAp3t2T5ZGI1AAvYoL2k9z4Dp3S8FVh7S0W9ImA08MX3QNYB9MgcRCt3xh5jsEevkctpDEC4ZGDtgQm1_hsZs-Hq-WFZlLihDaNZS_bibOP6D4qVXif6Kf6cAFhMr909rV-2Q_DNkw2YI3y3ThcuSRTdsVOsJhRlBDoco0NZfgdfJ1VB',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.6506469, 'lng': -73.75312339999999},
#     'viewport': {'northeast': {'lat': 42.65205538029149,
#       'lng': -73.75212566970848},
#      'southwest': {'lat': 42.64935741970849, 'lng': -73.7548236302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hilton Albany',
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114534858979559033885">Jerry Rogich</a>'],
#      'photo_reference': 'Aap_uECbTAJJUt-qVWyd4Qhl8WlVWI5riPjZAgFKjmb-w8sKICGcXLrfwDEFQDPnKXNwglvPot_6-ql39ZGE7CoCksuniodqhebu8KLPF725v8FNKd0dFbayYCCMHH--uEMGvvoHafZILJIph6MBgZ4CUY-EsKTk_YUv_QvhDJ3V6VM9G_UX',
#      'width': 3024}],
#    'place_id': 'ChIJKWgGHCQK3okRgxizNC_gd4U',
#    'plus_code': {'compound_code': 'M62W+7Q Albany, NY, USA',
#     'global_code': '87J8M62W+7Q'},
#    'rating': 3.6,
#    'reference': 'ChIJKWgGHCQK3okRgxizNC_gd4U',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2072,
#    'vicinity': '40 Lodge Street, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.6534971, 'lng': -73.75154789999999},
#     'viewport': {'northeast': {'lat': 42.65478333029149,
#       'lng': -73.75011621970849},
#      'southwest': {'lat': 42.65208536970849, 'lng': -73.7528141802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hampton Inn & Suites Albany-Downtown',
#    'photos': [{'height': 913,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111650991760080029985">Hampton Inn &amp; Suites Albany-Downtown</a>'],
#      'photo_reference': 'Aap_uEDUVu785NUSyqwXmpxwaAgtYHHSvdtB1dFEmEig8AVVj6OvzB-Dh6iL2y5cLjw9WLv1MGctsSVU4Rs6Zas-0VtDYTqzkwRl5doUXZyAhSdKVVAD8BiqeDRJ2_y9K874PUcYxieja-oNlAPG5R9ZbsrMUUHnKzj8Hg_HKgB3sF5h8AYK',
#      'width': 1280}],
#    'place_id': 'ChIJSfaaOiYK3okRfad-IU_ylKw',
#    'plus_code': {'compound_code': 'M63X+99 Albany, NY, USA',
#     'global_code': '87J8M63X+99'},
#    'rating': 4.1,
#    'reference': 'ChIJSfaaOiYK3okRfad-IU_ylKw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1036,
#    'vicinity': '25 Chapel Street, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.6454798, 'lng': -73.7504088},
#     'viewport': {'northeast': {'lat': 42.64695018029149,
#       'lng': -73.74877336970849},
#      'southwest': {'lat': 42.64425221970849, 'lng': -73.75147133029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Holiday Inn Express Albany - Downtown, an IHG Hotel',
#    'photos': [{'height': 1068,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103718494850107588219">Holiday Inn Express Albany - Downtown, an IHG Hotel</a>'],
#      'photo_reference': 'Aap_uECBMjsmMu_XaGryxpF8MIanqSS7o4LLkw4L-0cRvyk7ydy74CediE_f0Dsm0bB4dE-YI_DM-xMYIcx2qClvEHi7Ph7S9qQISJKjHJpFBd85_1MmLjFoENYFEdvMDGmiTa1X4TcfR0Wel6zk3iIhZ9kQRdpwbCDbuuBBYLhKuwuZg2Y0',
#      'width': 1900}],
#    'place_id': 'ChIJL5zANSAK3okRPegJyCn07pI',
#    'plus_code': {'compound_code': 'J6WX+5R Albany, NY, USA',
#     'global_code': '87J8J6WX+5R'},
#    'rating': 4.1,
#    'reference': 'ChIJL5zANSAK3okRPegJyCn07pI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 690,
#    'vicinity': '300 Broadway, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.6523365, 'lng': -73.7761732},
#     'viewport': {'northeast': {'lat': 42.6535400802915,
#       'lng': -73.77493756970851},
#      'southwest': {'lat': 42.6508421197085, 'lng': -73.77763553029152}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hilton Garden Inn Albany Medical Center',
#    'photos': [{'height': 1038,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111123195987860795364">Hilton Garden Inn Albany Medical Center</a>'],
#      'photo_reference': 'Aap_uECrWaNYS8-K1IzQyVhXkr30KDIof3iPwsbfpVACaq84hmVmxYqUjob2R7LYWMAwFGWxOa6VdjAso81oed9iGIsSZqvV4hMxutUvsF-d6ZNMO6sg1YNCsk_ZnBlfW7MC_O4KIYjwY7mO8XbkTHRMUkb6MDgdee9dvmUyN7mWD0S0NZ93',
#      'width': 2048}],
#    'place_id': 'ChIJKy_yWkEK3okRTST_YWO21QE',
#    'plus_code': {'compound_code': 'M62F+WG Albany, NY, USA',
#     'global_code': '87J8M62F+WG'},
#    'rating': 4.3,
#    'reference': 'ChIJKy_yWkEK3okRTST_YWO21QE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 693,
#    'vicinity': '62 New Scotland Avenue, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.68054890000001,
#      'lng': -73.78358349999999},
#     'viewport': {'northeast': {'lat': 42.6819097802915,
#       'lng': -73.78222376970848},
#      'southwest': {'lat': 42.6792118197085, 'lng': -73.7849217302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Ramada Plaza by Wyndham Albany',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107024876999517019966">Ramada Plaza by Wyndham Albany</a>'],
#      'photo_reference': 'Aap_uEAuly9S4SP1SdEB29HidDZ0rCvojCYZ_VyVTHRo81E0l5aiNw-eqOoQkJmjxWWhlsFkRAVN7DcNOZBRVDonmf8SWHxDMpHhT9rKyohJXsKpUlwk7yUWv1nX2VKNK7ODaskHO3MrC-zIAcV9eClsI-kpIO72yEdQwsWP7_Ro7B861WBz',
#      'width': 600}],
#    'place_id': 'ChIJC6CszaQL3okRrqdAMxjFB1o',
#    'plus_code': {'compound_code': 'M6J8+6H Albany, NY, USA',
#     'global_code': '87J8M6J8+6H'},
#    'rating': 2.4,
#    'reference': 'ChIJC6CszaQL3okRrqdAMxjFB1o',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1298,
#    'vicinity': '3 Watervliet Avenue Extension, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.672161, 'lng': -73.7511413},
#     'viewport': {'northeast': {'lat': 42.6736126802915,
#       'lng': -73.75000676970849},
#      'southwest': {'lat': 42.6709147197085, 'lng': -73.75270473029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Red Carpet Inn Northern Blvd. Albany, NY',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 719,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107613139966170038675">Red Carpet Inn Northern Blvd. Albany, NY</a>'],
#      'photo_reference': 'Aap_uEC9oudMzkHv1Q3flWBChm1-sCkru10jwYYxcK0KPT6HEm8ERxAjXM9cJBNE4e2j0Qr9SIiibijOXBK0lK8RdGhx-0ldUZfFmR4XYWGYxv6iA8wmvUOjGp9TjZet44Zm523sa-B9RZc2EgvnD4YDl0_0SxZWaPQxoEXFUgbdyg-fwJev',
#      'width': 1200}],
#    'place_id': 'ChIJL22xbtcL3okR_IDt60NTnf0',
#    'plus_code': {'compound_code': 'M6CX+VG Albany, NY, USA',
#     'global_code': '87J8M6CX+VG'},
#    'reference': 'ChIJL22xbtcL3okR_IDt60NTnf0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '500 Northern Boulevard, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.65694010000001,
#      'lng': -73.76573549999999},
#     'viewport': {'northeast': {'lat': 42.6582233802915,
#       'lng': -73.76445886970849},
#      'southwest': {'lat': 42.6555254197085, 'lng': -73.7671568302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Morgan State House Inn',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116827858303080099681">Morgan State House Inn</a>'],
#      'photo_reference': 'Aap_uEAFRtvlZwrzzG5kOcWPysq7VGrUD7eANtYyj_oiCibBSYykPu3_GamencljYxqecTefEmp0065oPkN0pGXDzZp_X-Al44CHLn79U5bKDtCVKFSDokAY2CnUqn2m_PoZo52hYmFLdfNfd3MtVz_mRCdRh5cBKtasoW8I84doD81bfpSd',
#      'width': 2880}],
#    'place_id': 'ChIJR9tBTDcK3okR2X-7lz38cVw',
#    'plus_code': {'compound_code': 'M64M+QP Albany, NY, USA',
#     'global_code': '87J8M64M+QP'},
#    'rating': 4.6,
#    'reference': 'ChIJR9tBTDcK3okR2X-7lz38cVw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 115,
#    'vicinity': '393 State Street, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.64625100000001, 'lng': -73.772409},
#     'viewport': {'northeast': {'lat': 42.6476791302915,
#       'lng': -73.77085616970848},
#      'southwest': {'lat': 42.6449811697085, 'lng': -73.7735541302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'TownePlace Suites by Marriott Albany Downtown/Medical Center',
#    'photos': [{'height': 1366,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115968308554601824004">TownePlace Suites by Marriott Albany Downtown/Medical Center</a>'],
#      'photo_reference': 'Aap_uEAaAcSd6V528sDZeQ8_iEkBYDx2ftb5QOJ1H6xKABS2DAlBb5XLPJKv11IseenEo5l8_ekyzSf3PRkP1B6DIZak8nKOjK9a-artP6Lj3HI0UBVS3or4xGH4YY1xKq3EeZ-kmfKz7CPZBdSTgYy50pSs0s5VR_vukmnBQ42wE3VoW77j',
#      'width': 2048}],
#    'place_id': 'ChIJdzuvwWoK3okRahCD-RVk2zg',
#    'plus_code': {'compound_code': 'J6WH+G2 Albany, NY, USA',
#     'global_code': '87J8J6WH+G2'},
#    'rating': 4.2,
#    'reference': 'ChIJdzuvwWoK3okRahCD-RVk2zg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 412,
#    'vicinity': '22 Holland Avenue, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.6791635, 'lng': -73.7827185},
#     'viewport': {'northeast': {'lat': 42.6806668302915,
#       'lng': -73.78165966970849},
#      'southwest': {'lat': 42.6779688697085, 'lng': -73.78435763029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Motel 6 Albany, NY',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1907,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103947272161323415151">Motel 6 Albany, NY</a>'],
#      'photo_reference': 'Aap_uECacD9xYGwcOSTWPD6Xz6LsJh4ue93YPjdBF5iLNVUPJfzxB-u21cIb5X9GN7dNg2gorl9VWaooOL7A4AobicrOUJNU0K2AEZDcpzkc2w7tvSoNXCJBCC4IGO9XDPnHy7l33fMCfp9-RqUXZqTG7rDgMDObKbx64LAeeb1jahobq0t1',
#      'width': 2879}],
#    'place_id': 'ChIJ88vVnsYI3okRo00kUtKq_CQ',
#    'plus_code': {'compound_code': 'M6H8+MW Albany, NY, USA',
#     'global_code': '87J8M6H8+MW'},
#    'rating': 3,
#    'reference': 'ChIJ88vVnsYI3okRo00kUtKq_CQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1175,
#    'vicinity': '100 Watervliet Avenue, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.632346, 'lng': -73.70176699999999},
#     'viewport': {'northeast': {'lat': 42.6342798, 'lng': -73.70055716970847},
#      'southwest': {'lat': 42.6301782, 'lng': -73.7032551302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Holiday Inn Express & Suites East Greenbush(Albany-Skyline), an IHG Hotel',
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104006022187463878753">Owned St</a>'],
#      'photo_reference': 'Aap_uEADHjwX165TsG1-cbtwXX9CPv8OYw-j_Zw0DcNkD9h4wgMfw1b8nhoZwFoUA8e21uSlvOZ8wM7elXN8FAQ-LeImTPfV_F-Xj_dghBoDySUsNdNj6u6QuO-DaAh0nXqk4fWNuCJjuqJMLnP9v-BsAIClmIg61DtpH9T-d6-qnE6agFBU',
#      'width': 4000}],
#    'place_id': 'ChIJkeITo8wJ3okRGmrpMoNTogE',
#    'plus_code': {'compound_code': 'J7JX+W7 Rensselaer, NY, USA',
#     'global_code': '87J8J7JX+W7'},
#    'rating': 4,
#    'reference': 'ChIJkeITo8wJ3okRGmrpMoNTogE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 374,
#    'vicinity': '8 Empire Drive, Rensselaer'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.622228, 'lng': -73.778481},
#     'viewport': {'northeast': {'lat': 42.6237731802915,
#       'lng': -73.7769034197085},
#      'southwest': {'lat': 42.6210752197085, 'lng': -73.77960138029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Comfort Inn Glenmont - Albany South',
#    'photos': [{'height': 5504,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111452139386596809796">Comfort Inn Glenmont - Albany South</a>'],
#      'photo_reference': 'Aap_uEDEmLhDl6zOUw9t-9New7y9aTw1yFH86SK52ZR9yFCBB_jwkhx1A01-6dxuBqK1i8ZqEp9blgeJyLf-M2KjdyKpt7XlpoTcYm5Yt7MyHlO__iQT7WZUehzpGXIwVsOc7eZ2mB6QZkBhFz5x9sljb7Uyy5kzpvBuhVXWxb88rV2iQ6Wi',
#      'width': 8256}],
#    'place_id': 'ChIJ4Tr4dNvh3YkR3t-VH5cTc28',
#    'plus_code': {'compound_code': 'J6CC+VJ Glenmont, NY, USA',
#     'global_code': '87J8J6CC+VJ'},
#    'rating': 3.9,
#    'reference': 'ChIJ4Tr4dNvh3YkR3t-VH5cTc28',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 406,
#    'vicinity': '37 Route 9W, Glenmont'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.6590462, 'lng': -73.7835343},
#     'viewport': {'northeast': {'lat': 42.6604230802915,
#       'lng': -73.78223121970849},
#      'southwest': {'lat': 42.6577251197085, 'lng': -73.7849291802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Luxury Studio in the Old Plumbers Union Building',
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106442656581071151059">Manuel Velecela</a>'],
#      'photo_reference': 'Aap_uEAZQwav79Jmv3ut7i_MN6JZgi1y7WU-3eTk2vRCXh92sv6PiRRISdwIJxVNEcwHNn9Mitb5MUC-XGjBTWv1tyeqzQVd4j0Se-YmbwdOi9uoQ26yD_wcX6huZ4SIPrLbOo1Pxvh_3bAHURlXpecNCIGXEOLtp3c4TaZJLSgs9r1WvZCg',
#      'width': 2080}],
#    'place_id': 'ChIJ__8YBFAK3okRx_qBQTtYSsY',
#    'plus_code': {'compound_code': 'M658+JH Albany, NY, USA',
#     'global_code': '87J8M658+JH'},
#    'rating': 5,
#    'reference': 'ChIJ__8YBFAK3okRx_qBQTtYSsY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '328 Ontario Street, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.6201186, 'lng': -73.7824613},
#     'viewport': {'northeast': {'lat': 42.6215211802915,
#       'lng': -73.78105961970849},
#      'southwest': {'lat': 42.6188232197085, 'lng': -73.7837575802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Quality Inn & Suites Glenmont - Albany South',
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107568795897307719588">Quality Inn &amp; Suites Glenmont - Albany South</a>'],
#      'photo_reference': 'Aap_uEAU1E_SRKyT3aVhhhsitw8Jv0j0uoUYl1AdXq0PAtWrY6YtZf1FkQwfnVO_ha7T8lCMaa9CkwJbP3VkBukiqnDOWUu3vpRQgHiZCJjZTnyZw8ahhbK1Ada_iaRbjQ_zlmyFpJAJUTQn_4tT7wq_wy_uBX2ohWlxHHJFVwdy3DhlhwdM',
#      'width': 2880}],
#    'place_id': 'ChIJvZZVUMXh3YkRLSgEoMYE2sA',
#    'plus_code': {'compound_code': 'J6C9+22 Glenmont, NY, USA',
#     'global_code': '87J8J6C9+22'},
#    'rating': 3.5,
#    'reference': 'ChIJvZZVUMXh3YkRLSgEoMYE2sA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 220,
#    'vicinity': '15 Frontage Road, Glenmont'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.67893, 'lng': -73.78570959999999},
#     'viewport': {'northeast': {'lat': 42.68019898029151,
#       'lng': -73.78427086970851},
#      'southwest': {'lat': 42.67750101970851, 'lng': -73.78696883029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Unite Here',
#    'place_id': 'ChIJ9yytgqUL3okR6rWwRfirvcg',
#    'plus_code': {'compound_code': 'M6H7+HP Albany, NY, USA',
#     'global_code': '87J8M6H7+HP'},
#    'reference': 'ChIJ9yytgqUL3okR6rWwRfirvcg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '890 3rd Street, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.654514, 'lng': -73.761222},
#     'viewport': {'northeast': {'lat': 42.65573793029149,
#       'lng': -73.76000731970849},
#      'southwest': {'lat': 42.65303996970849, 'lng': -73.76270528029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'State Street Mansion B & B',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109865883714498258621">David Bardi</a>'],
#      'photo_reference': 'Aap_uEAKwUhBMbVBgc2wTUQMFDM9_Ky5NVvtyL0AVX0XT0V44HQxDjy4kR774Y_iWIGbRU6PRJdWHDsWg5T8zKINoc7MPI9pcSBBuWiQW8Acj9ofNCwNHr5OKjE0cYCdTRbNY42C5OZ0vv1c4J3A2ZdmH_Fbigqg_4xym2G8THoe_SxxTzA',
#      'width': 4032}],
#    'place_id': 'ChIJFXpKlDoK3okRIJVFnbCuE5k',
#    'plus_code': {'compound_code': 'M63Q+RG Albany, NY, USA',
#     'global_code': '87J8M63Q+RG'},
#    'rating': 3,
#    'reference': 'ChIJFXpKlDoK3okRIJVFnbCuE5k',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': '281 State Street, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.6493659, 'lng': -73.75236249999999},
#     'viewport': {'northeast': {'lat': 42.6507735302915,
#       'lng': -73.7509468697085},
#      'southwest': {'lat': 42.6480755697085, 'lng': -73.7536448302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Fairfield Inn & Suites by Marriott Albany Downtown',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114404239660466879084">Fairfield by Marriott Albany Downtown</a>'],
#      'photo_reference': 'Aap_uEClu8PfNIJKeNHMokL78-RuUUq1flSvghHcbYPLCUIoZ7MmFY_z6out58a6lAlq-KZm8EGtJ_ns8yT0zFHdqh1f0at1sf57hw9buFvKiNKui1TJtawHDX54xRtLCOck9ECI2jhViMnuoa-akiHXDH7tZHSniht4FZpay_qrIORkOEKI',
#      'width': 1440}],
#    'place_id': 'ChIJH0vgSyEK3okRHx1ZQiyc2pY',
#    'plus_code': {'compound_code': 'J6XX+P3 Albany, NY, USA',
#     'global_code': '87J8J6XX+P3'},
#    'rating': 4.2,
#    'reference': 'ChIJH0vgSyEK3okRHx1ZQiyc2pY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 331,
#    'vicinity': '74 State Street, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.6506249, 'lng': -73.75568659999999},
#     'viewport': {'northeast': {'lat': 42.65203993029149,
#       'lng': -73.7544551197085},
#      'southwest': {'lat': 42.6493419697085, 'lng': -73.7571530802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Renaissance Albany Hotel',
#    'photos': [{'height': 1366,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101293000106046928215">Renaissance Albany Hotel</a>'],
#      'photo_reference': 'Aap_uEBJUkDYLwy-MhueNE0VNsKllNcVtMTly0GfV1Lxi08fK6tbmxBTz3Qs33CygC9drWTv09ERoPGvcNu4f-Urj7VakiuRpPugTZ_gWqOStkPBJgNub2i-rDA8baJ_twj81bY6S57eGdw-qQmh1iIKfMP7r4PE1nqd52exuaNnuhH-hYmg',
#      'width': 2048}],
#    'place_id': 'ChIJx2L-biQK3okRK89Cs53bHvk',
#    'plus_code': {'compound_code': 'M62V+6P Albany, NY, USA',
#     'global_code': '87J8M62V+6P'},
#    'rating': 4.5,
#    'reference': 'ChIJx2L-biQK3okRK89Cs53bHvk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 967,
#    'vicinity': '144 State Street, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.65291330000001, 'lng': -73.763228},
#     'viewport': {'northeast': {'lat': 42.6542358802915,
#       'lng': -73.76190561970849},
#      'southwest': {'lat': 42.65153791970851, 'lng': -73.7646035802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'DPH CONCIERGE Pet Assistance',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 739,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113044302802872181844">DPH CONCIERGE LLC- PETS</a>'],
#      'photo_reference': 'Aap_uECnflsRo1VZ3rfp69-eeT6IIgmQ9UeXWs6UmMV1ECH3L9K4LtDLuF81J373r58xFEwzK6CEBy4uc7fOpw59QwkLxMctCrz28oeWMILhucq3SULUptbv7R5SC8qR6Bcshzd2pZXxgyBX-fYdntAB1frDK4jYl-SRSFaOgX6l72h1qSdr',
#      'width': 1125}],
#    'place_id': 'ChIJzabQLjoK3okR4KaI3YxAs8k',
#    'plus_code': {'compound_code': 'M63P+5P Albany, NY, USA',
#     'global_code': '87J8M63P+5P'},
#    'rating': 3.7,
#    'reference': 'ChIJzabQLjoK3okR4KaI3YxAs8k',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Jay Street, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.65634470000001,
#      'lng': -73.77521569999999},
#     'viewport': {'northeast': {'lat': 42.65781198029149,
#       'lng': -73.77372796970849},
#      'southwest': {'lat': 42.6551140197085, 'lng': -73.7764259302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Washington Park Inn',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 680,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113989571662249685289">Washington Park Inn</a>'],
#      'photo_reference': 'Aap_uEDMFn-gPX2orGDxaNOa795B4pVXayl87PxWGeXZc6EVMWa8GohwgjoL1gjDn7ijx1eYxRTkmMAChR0y9sBqpnYNQyf-y7cPhiqvxsICuR_EZRBgMORKCZi3DA-5OSSxzCwXM69AvZIOQ9-0EMpop3Rg4nIpaC9tSNZXXhflKgy3QFab',
#      'width': 1024}],
#    'place_id': 'ChIJCYc3QkYK3okRNXP_3YbTNYw',
#    'plus_code': {'compound_code': 'M64F+GW Albany, NY, USA',
#     'global_code': '87J8M64F+GW'},
#    'rating': 4.5,
#    'reference': 'ChIJCYc3QkYK3okRNXP_3YbTNYw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 80,
#    'vicinity': '634 Madison Avenue, Albany'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.622981, 'lng': -73.736952},
#     'viewport': {'northeast': {'lat': 42.6244694302915,
#       'lng': -73.7357132197085},
#      'southwest': {'lat': 42.6217714697085, 'lng': -73.73841118029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Spaulding House',
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102763353904267974892">Nicholas DiGaudio</a>'],
#      'photo_reference': 'Aap_uEDirw4g68FfuH0sf3_cYvOYpVj69UE8JllOx81nbFsxsX4Fq12jzqwS2ZR_--XO5DydBNGC9mX1OuaD_29F-tt6b_uWG7hGxvLUbIy85iiF3zqeN32060cv2YkhhnDUthp_o396blLdrlnDK9UxvgfcBI8_UVjpfzGupgMzhvX62yU',
#      'width': 4032}],
#    'place_id': 'ChIJnTsh8Qfi3YkRVV0RfYa2ONo',
#    'plus_code': {'compound_code': 'J7F7+56 Rensselaer, NY, USA',
#     'global_code': '87J8J7F7+56'},
#    'rating': 4.3,
#    'reference': 'ChIJnTsh8Qfi3YkRVV0RfYa2ONo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 16,
#    'vicinity': '10 Bruen Court, Rensselaer'}],
#  'status': 'OK'}

# %%
len(hotels["results"])
# Out:
# 20

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
# Grab the first hotel from the results and store the name.
try:
    hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
except (IndexError):
    print("Hotel not found... skipping.")

# %%
# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]

    # 6d. Make request and retrieve the JSON data from the search.
    params["location"] = f"{lat},{lng}"

    # 6e. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
# 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
try:
    hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
except (IndexError):
    print("Hotel not found... skipping.")

# %%
hotel_df.head(10)
# Out:
#             City Country  Max Temp      Lat       Lng  \
# 1         Atuona      PF    78.854  -9.8000 -139.0333
# 3     Butaritari      KI    79.628   3.0707  172.7902
# 6   Puerto Ayora      EC    80.564  -0.7393  -90.3518
# 11        Lakota      CI    87.944   5.8528   -5.6883
# 13     Mount Isa      AU    83.966 -20.7333  139.5000
# 16       Rikitea      PF    78.908 -23.1203 -134.9692
# 24      Saldanha      ZA    84.254 -33.0117   17.9442
# 26        Olinda      BR    85.730  -8.0089  -34.8553
# 32        Castro      BR    77.054 -24.7911  -50.0119
# 35  Komsomolskiy      UZ    77.720  40.4272   71.7189
#
#                    Hotel Name
# 1                 Villa Enata
# 3          Isles Sunset Lodge
# 6   Finch Bay Galapagos Hotel
# 11            Aziz bah divers
# 13  ibis Styles Mt Isa Verona
# 16            People ThankYou
# 24        Club Mykonos Resort
# 26         Recife Plaza Hotel
# 32      L'acqua Motel Express
# 35          Grand Osiyo Plaza

# %%
import numpy as np

# %%
hotel_df['Hotel Name'].replace('', np.nan, inplace=True)

# %%
hotel_df['Hotel Name'].replace('0', np.nan, inplace=True)

# %%
hotel_df.isnull().sum()
# Out:
# City           0
# Country        0
# Max Temp       0
# Lat            0
# Lng            0
# Hotel Name    64
# dtype: int64

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()

# %%
clean_hotel_df.head(10)
# Out:
#             City Country  Max Temp      Lat       Lng  \
# 1         Atuona      PF    78.854  -9.8000 -139.0333
# 3     Butaritari      KI    79.628   3.0707  172.7902
# 6   Puerto Ayora      EC    80.564  -0.7393  -90.3518
# 11        Lakota      CI    87.944   5.8528   -5.6883
# 13     Mount Isa      AU    83.966 -20.7333  139.5000
# 16       Rikitea      PF    78.908 -23.1203 -134.9692
# 24      Saldanha      ZA    84.254 -33.0117   17.9442
# 26        Olinda      BR    85.730  -8.0089  -34.8553
# 32        Castro      BR    77.054 -24.7911  -50.0119
# 35  Komsomolskiy      UZ    77.720  40.4272   71.7189
#
#                    Hotel Name
# 1                 Villa Enata
# 3          Isles Sunset Lodge
# 6   Finch Bay Galapagos Hotel
# 11            Aziz bah divers
# 13  ibis Styles Mt Isa Verona
# 16            People ThankYou
# 24        Club Mykonos Resort
# 26         Recife Plaza Hotel
# 32      L'acqua Motel Express
# 35          Grand Osiyo Plaza

# %%
# 8a. Create the output File (CSV)
#output_data_file = "C:\\Users\\Blaine\\Documents\\College\\Bootcamp\\World_Weather_Analysis\\Weather_Database\\WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
#clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
# Add a heatmap of temperature for the vacation spots.
max_temp = clean_hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
